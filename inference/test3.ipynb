# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/jampanasasank/Desktop/Customer Churn Prediction/Customer-Churn-Prediction/inference

# %%
from predictor import Prediction

# %%
model_path = '/home/jampanasasank/Desktop/Customer Churn Prediction/Customer-Churn-Prediction/model'

# %%
test_data = pd.read_csv("/home/jampanasasank/Desktop/Customer Churn Prediction/Customer-Churn-Prediction/AllData/archive (6)/autoinsurance_churn.csv")

test_data = test_data.sample(100)
test_data.drop(['Churn'], axis=1, inplace=True)

# %%
test_data
# Out:
#          individual_id    address_id  curr_ann_amt  days_tenure  \
# 1036742   2.213017e+11  5.213006e+11    759.574322       6291.0
# 1611618   2.213001e+11  5.213000e+11    905.313134       4608.0
# 722448    2.213013e+11  5.213005e+11   1012.606496       3143.0
# 1193730   2.213032e+11  5.213015e+11    562.544822        125.0
# 1271814   2.213003e+11  5.213001e+11   1134.328089       1283.0
# ...                ...           ...           ...          ...
# 449980    2.213031e+11  5.213013e+11   1507.205345       6291.0
# 1114334   2.213024e+11  5.213009e+11    722.087522        173.0
# 577080    2.213030e+11  5.213013e+11   1009.788696       3336.0
# 721308    2.213025e+11  5.213009e+11    575.194958       5884.0
# 340580    2.213031e+11  5.213013e+11   1049.564599       3372.0
#
#         cust_orig_date  age_in_years date_of_birth   latitude  longitude  \
# 1036742     2005-09-11            41    1982-01-20  33.126078 -96.647765
# ...

# %%
obj = Prediction(model_path=model_path)

_ , df = obj.make_prediction(data=test_data)
# Out:
# Model Loaded..
# Loaded the estimators...
# {'mice_imputer_estimator': IterativeImputer(random_state=42), 'county_label_encoder_estimator': LabelEncoder(), 'city_label_encoder_estimator': LabelEncoder(), 'marital_status_label_encoder_estimator': LabelEncoder(), 'model': XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=1, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.15, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=9, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=110, n_jobs=None,
# ...

# %%
df
# Out:
#          individual_id  prediction
# 1036742   2.213017e+11           0
# 1611618   2.213001e+11           0
# 722448    2.213013e+11           0
# 1193730   2.213032e+11           1
# 1271814   2.213003e+11           0
# ...                ...         ...
# 449980    2.213031e+11           0
# 1114334   2.213024e+11           1
# 577080    2.213030e+11           0
# 721308    2.213025e+11           0
# 340580    2.213031e+11           0
#
# [100 rows x 2 columns]
